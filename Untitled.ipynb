# %%
import pandas as pd

# %%
# Load the data into Python
df = pd.read_csv("data.csv")

# %%
#Transforming the data
df2 = df.dropna()

df3 = df.dropna(subset=['Age'])
df3.head()
df3 = df.Age.dropna()

# %%
df['Age'].median()
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.loc[df['Sex'] == 'male']
df.loc[df['Sex'] == 'male', 'Sex']
df.loc[df["Sex"] == "male", "Sex"] = "M"
df.loc[df["Sex"] == "female", "Sex"] = "F"

# %%
#Who were the titanic passangers?
import seaborn as sns
# %matplotlib inline
sns.catplot("Sex", data=df, kind="count")
sns.catplot("Pclass", data = df, kind = 'count')
sns.catplot("Pclass", data=df, hue="Sex", kind = "count")

# %%
#What about the children?
def man_woman_child(passenger):
    age, sex = passenger
    if age < 16:
        return "C"
    else:
        return sex

# %%
df["who"] = df[["Age", "Sex"]].apply(man_woman_child, axis=1)
sns.catplot("who", data=df, kind = "count");

# %%
#Where were our passenger's cabin
df["deck"] = df.Cabin.str[0]
sns.catplot("deck", data=df, palette="BuPu_d", kind = "count", order = ['A','B','C','D','E','F','G','T'])

# %%
df.loc[df.Cabin == 'T']
df = df.loc[df.deck != "T"]
sns.catplot("deck", data=df, palette="BuPu_d", kind = "count");

# %%
#How much did they pay for their tickets
#sns.factorplot("deck", "Fare", data=df, palette="PuBu_d", kind = "bar");
A = df.loc[df["deck"] == "A"]
A.describe()
# Out:
#        PassengerId   Survived  Pclass        Age      SibSp      Parch  \
# count    15.000000  15.000000    15.0  15.000000  15.000000  15.000000
# mean    439.600000   0.466667     1.0  41.466667   0.133333   0.133333
# std     262.044653   0.516398     0.0  19.190275   0.351866   0.516398
# min      24.000000   0.000000     1.0   4.000000   0.000000   0.000000
# 25%     198.000000   0.000000     1.0  28.000000   0.000000   0.000000
# 50%     476.000000   0.000000     1.0  39.000000   0.000000   0.000000
# 75%     615.500000   1.000000     1.0  52.500000   0.000000   0.000000
# max     868.000000   1.000000     1.0  80.000000   1.000000   2.000000
#
#             Fare
# count  15.000000
# mean   39.623887
# std    17.975333
# min     0.000000
# 25%    30.847900
# 50%    35.500000
# 75%    50.247900
# max    81.858300

# %%
deckOrder=['A','B','C','D','E','F','G','T']
sns.catplot("deck", "Fare", kind = 'box',data=df, order = deckOrder);
sns.catplot("deck", "Fare", kind = 'box',data=df, order = deckOrder).set(ylim=(0,300))
C = df.loc[df["deck"] == "B"]
C.describe()
# Out:
#        PassengerId   Survived  Pclass        Age      SibSp      Parch  \
# count    47.000000  47.000000    47.0  47.000000  47.000000  47.000000
# mean    521.808511   0.744681     1.0  34.659574   0.361702   0.574468
# std     252.725116   0.440755     0.0  15.217662   0.568198   0.773043
# min      32.000000   0.000000     1.0  11.000000   0.000000   0.000000
# 25%     306.000000   0.500000     1.0  24.000000   0.000000   0.000000
# 50%     540.000000   1.000000     1.0  32.000000   0.000000   0.000000
# 75%     744.500000   1.000000     1.0  44.000000   1.000000   1.000000
# max     888.000000   1.000000     1.0  70.000000   2.000000   2.000000
#
#              Fare
# count   47.000000
# mean   113.505764
# std    109.301500
# min      0.000000
# 25%     57.000000
# 50%     80.000000
# 75%    120.000000
# max    512.329200

# %%
#What made people survive the sinking
sns.catplot("Pclass", "Survived", data=df,kind='point').set(ylim=(0, 1))
sns.catplot("Pclass", "Survived", data=df, hue="Sex", kind='point').set(ylim=(0, 1));

# %%
df.loc[(df.Pclass == 2) & (df.Sex == 'F')].describe()
# Out:
#        PassengerId   Survived  Pclass        Age      SibSp      Parch  \
# count    76.000000  76.000000    76.0  76.000000  76.000000  76.000000
# mean    443.105263   0.921053     2.0  28.703947   0.486842   0.605263
# std     243.627288   0.271448     0.0  12.700440   0.642774   0.833930
# min      10.000000   0.000000     2.0   2.000000   0.000000   0.000000
# 25%     269.750000   1.000000     2.0  22.750000   0.000000   0.000000
# 50%     439.500000   1.000000     2.0  28.000000   0.000000   0.000000
# 75%     616.750000   1.000000     2.0  36.000000   1.000000   1.000000
# max     881.000000   1.000000     2.0  57.000000   3.000000   3.000000
#
#             Fare
# count  76.000000
# mean   21.970121
# std    10.891796
# min    10.500000
# 25%    13.000000
# 50%    22.000000
# 75%    26.062500
# max    65.000000

# %%
df.loc[(df.Pclass == 2) & (df.Sex == 'M')].describe()
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   108.000000  108.000000   108.0  108.000000  108.000000  108.000000
# mean    447.962963    0.157407     2.0   30.512315    0.342593    0.222222
# std     256.922546    0.365882     0.0   14.178495    0.566380    0.517603
# min      18.000000    0.000000     2.0    0.670000    0.000000    0.000000
# 25%     225.750000    0.000000     2.0   23.000000    0.000000    0.000000
# 50%     416.500000    0.000000     2.0   29.000000    0.000000    0.000000
# 75%     677.500000    0.000000     2.0   36.000000    1.000000    0.000000
# max     887.000000    1.000000     2.0   70.000000    2.000000    2.000000
#
#              Fare
# count  108.000000
# mean    19.741782
# std     14.922235
# min      0.000000
# 25%     12.331250
# 50%     13.000000
# 75%     26.000000
# max     73.500000

# %%
sns.catplot("Pclass", "Survived", data=df, hue="who", kind='point', ci = 0).set(ylim=(0, 1))
